# %%
from src import available_models, get_model, MODEL_REGISTRY



import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST, CIFAR100
from medmnist import PathMNIST
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch.nn.functional as F
from dataset import MergedMedMNIST
from medmnist import INFO



### Prep Dataset ###
tensor_transforms = transforms.Compose(
    [
        transforms.Resize((128,128)),
        transforms.ToTensor(),
    ]
)

# train_set = MergedMedMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="train", transform=tensor_transforms, download=False, size=224)
# test_set = MergedMedMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="test", transform=tensor_transforms, download=False, size=224)

# train_set = PathMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="train", transform=tensor_transforms, download=False, size=224)
# test_set = PathMNIST(root="/vol/miltank/users/bubeckn/MedMNIST", split="test", transform=tensor_transforms, download=False, size=224)

train_set = CIFAR100(root=".", train=True, transform=tensor_transforms, download=False)
test_set = CIFAR100(root=".", train=False, transform=tensor_transforms, download=False)

### Set Device ###
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# attention mode is flash
# Loaded pretrained weights

# %%
def train(model,
          train_set,
          test_set,
          batch_size,
          num_epochs,
          evaluation_iterations):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    model = model.to(device)

    trainloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    testloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=8)

    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    train_losses = []
    evaluation_losses = []

    steps_per_epoch = len(trainloader)
    total_steps = steps_per_epoch * num_epochs
    step_counter = 0
    train_loss_running = []
    evaluation_loss_running = []

    with tqdm(total=num_epochs, desc="Epochs") as epoch_bar:
        for epoch in range(num_epochs):
            model.train()
            with tqdm(total=steps_per_epoch, desc=f"Epoch {epoch+1}/{num_epochs} | loss: N/A", leave=False) as pbar:
                for images, labels in trainloader:
                    images = images.to(device)

                    recon, extra_loss = model(images)
                    loss = F.mse_loss(recon, images) +  extra_loss
                    # Update tqdm description with current loss value
                    pbar.set_description(f"Epoch {epoch+1}/{num_epochs} | loss: {loss.item():.4f}")

                    train_loss_running.append(loss.item())

                    loss.backward()
                    optimizer.step()
                    optimizer.zero_grad()

                    step_counter += 1
                    pbar.update(1)

                    # Evaluate every evaluation_iterations global step
                    if step_counter % evaluation_iterations == 0:
                        model.eval()
                        evaluation_loss_running.clear()
                        example_shown = False
                        with torch.no_grad():
                            for images_eval, labels_eval in testloader:
                                images_eval = images_eval.to(device)
                                recon_eval, _ = model(images_eval)
                                # Compute PSNR loss
                                mse = F.mse_loss(recon_eval, images_eval)
                                # Clamp to avoid log(0); add small epsilon
                                epsilon = 1e-8
                                psnr = 10 * torch.log10(1.0 / (mse + epsilon))
                                loss_eval = psnr
                                evaluation_loss_running.append(loss_eval.item())
                                
                                if not example_shown:

                                    def prep(img):
                                        img = img.detach().cpu()
                                        return img.squeeze(0) if img.shape[0] == 1 else img.permute(1, 2, 0)

                                    inp = prep(images_eval[0])
                                    rec = prep(recon_eval[0])
                                    cmap = "gray" if inp.ndim == 2 else None

                                    fig, axes = plt.subplots(1, 2, figsize=(6, 3))
                                    titles = ["Input", "Reconstruction"]

                                    for ax, data, title in zip(axes, [inp, rec], titles):
                                        ax.imshow(data, cmap=cmap)
                                        ax.set_title(title)
                                        ax.axis("off")

                                    plt.suptitle(f"Eval Example at Step {step_counter}")
                                    plt.tight_layout()
                                    plt.show()

                                    example_shown = True

                        train_loss_val = np.mean(train_loss_running) if train_loss_running else 0.0
                        evaluation_loss_val = np.mean(evaluation_loss_running) if evaluation_loss_running else 0.0
                        train_losses.append(train_loss_val)
                        evaluation_losses.append(evaluation_loss_val)
                        train_loss_running = []
                        model.train()
            epoch_bar.update(1)

    print("Final Training Loss", train_losses[-1] if train_losses else "No log")
    print("Final Evaluation Loss", evaluation_losses[-1] if evaluation_losses else "No log")

    return model, train_losses, evaluation_losses

# %%
all_models = available_models()
print(all_models)
f4_models = [name for name in all_models if "f4" in name]
print("All models with 'f4' in the name:", f4_models)

# for model_name in f4_models:
f4 = get_model("token.titok.b_64", image_size=[128, 128], patch_size=[8, 8], in_channels=3, out_channels=3, stage="e2e")

linear_ae, train_losses, evaluation_losses = train(f4,
                                                train_set=train_set,
                                                test_set=test_set,
                                                batch_size=8,
                                                num_epochs=10,
                                                evaluation_iterations=1000)
# Out:
# ('continuous.aekl.f16_d8', 'continuous.aekl.f32_d64', 'continuous.aekl.f4_d3', 'continuous.aekl.f8_d4', 'continuous.maisi.f4_d3', 'discrete.fsq.f16_d256_e10', 'discrete.fsq.f16_d256_e12', 'discrete.fsq.f16_d256_e14', 'discrete.fsq.f16_d256_e16', 'discrete.fsq.f16_d256_e8', 'discrete.lfq.f16_b10', 'discrete.lfq.f16_b12', 'discrete.lfq.f16_b14', 'discrete.lfq.f16_b16', 'discrete.lfq.f16_b18', 'discrete.maskgit.vq.f16_d256_e1024', 'discrete.msrq.f16_d32_e4096', 'discrete.qinco.f16_d8_e16384', 'discrete.qinco.f4_d3_e8192', 'discrete.qinco.f8_d4_e16384', 'discrete.quantizer.finite_scalar_quantizer', 'discrete.quantizer.grouped_residual_quantizer', 'discrete.quantizer.gumbel_quantizer', 'discrete.quantizer.lookup_free_quantizer', 'discrete.quantizer.msrq_vector_quantizer2', 'discrete.quantizer.qinco_vector_quantizer', 'discrete.quantizer.residual_quantizer', 'discrete.quantizer.vector_quantizer', 'discrete.quantizer.vector_quantizer2', 'discrete.simvq.f16_d8_e16384', 'discrete.simvq.f4_d3_e8192', 'discrete.simvq.f8_d4_e16384', 'discrete.vq.f16_d8_e16384', 'discrete.vq.f4_d3_e8192', 'discrete.vq.f8_d4_e16384', 'token.detok.bb', 'token.detok.bl', 'token.detok.bs', 'token.detok.lb', 'token.detok.ll', 'token.detok.ls', 'token.detok.sb', 'token.detok.sl', 'token.detok.ss', 'token.detok.xlxl', 'token.maetok.b_128', 'token.titok.b_64', 'token.titok.l_32', 'token.titok.s_128', 'token.vita.reconmae')
# All models with 'f4' in the name: ['continuous.aekl.f4_d3', 'continuous.maisi.f4_d3', 'discrete.qinco.f4_d3_e8192', 'discrete.simvq.f4_d3_e8192', 'discrete.vq.f4_d3_e8192']
# num latent tokens: 64
# Epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 | loss: N/A:   0%|          | 0/6250 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 # for model_name in f4_models:
#       7 f4 = get_model("token.titok.b_64", image_size=[128, 128], patch_size=[8, 8], in_channels=3, out_channels=3, stage="e2e")
# ----> 9 linear_ae, train_losses, evaluation_losses = train(f4,
#      10                                                 train_set=train_set,
#      11                                                 test_set=test_set,
#      12                                                 batch_size=8,
#      13                                                 num_epochs=10,
#      14                                                 evaluation_iterations=1000)
#
# Cell In[2], line 55, in train(model, train_set, test_set, batch_size, num_epochs, evaluation_iterations)
#      53 for images_eval, labels_eval in testloader:
#      54     images_eval = images_eval.to(device)
# ---> 55     recon_eval, _ = model(images_eval)
#      56     # Compute PSNR loss
#      57     mse = F.mse_loss(recon_eval, images_eval)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /vol/miltank/users/bubeckn/MedTok/src/token/titok/titok.py:283, in TiTok.forward(self, x)
#     282 def forward(self, x):
# --> 283     z_quantized, loss = self.encode(x)
#     284     decoded = self.decode(z_quantized)
#     285     return decoded, loss
#
# File /vol/miltank/users/bubeckn/MedTok/src/token/titok/titok.py:242, in TiTok.encode(self, x)
#     240 z = self.encoder(pixel_values=x, latent_tokens=self.latent_tokens)
#     241 if self.quantize_mode == "vq":
# --> 242     z_quantized, loss, (perplexity, min_encodings, min_encoding_indices) = self.quantize(z)
#     243 elif self.quantize_mode == "vae":
#     244     posteriors = self.quantize(z)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/.conda/envs/automed/lib/python3.11/site-packages/torch/amp/autocast_mode.py:44, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      41 @functools.wraps(func)
#      42 def decorate_autocast(*args, **kwargs):
#      43     with autocast_instance:
# ---> 44         return func(*args, **kwargs)
#
# File /vol/miltank/users/bubeckn/MedTok/src/discrete/quantizer/quantize.py:321, in VectorQuantizer2.forward(self, z)
#     315     loss = self.beta * torch.mean((z_q.detach() - z) ** 2) + \
#     316            torch.mean((z_q - z.detach()) ** 2)
#     318 # ---------------------------
#     319 #       ENTROPY LOSS
#     320 # ---------------------------
# --> 321 entropy_loss = torch.tensor(0.0, device=z.device)
#     323 if self.entropy_loss_ratio > 0:
#     324     logits = -d  # MaskGIT uses negative distances as logits
#
# KeyboardInterrupt:

# %%
generated_index = 150
image, label = test_set[generated_index]

# Add batch dimension, move to device
image = image.unsqueeze(0).to(device)

# Forward pass
recon, _ = f4(image)

# Move to CPU, remove batch dim → shape: (C, H, W)
recon = recon.cpu().detach().squeeze()

# Convert to H×W×C (RGB) or H×W (grayscale)
if recon.ndim == 3:                 # C,H,W
    if recon.shape[0] == 1:         # grayscale
        recon = recon.squeeze(0)    # → H,W
        cmap = "gray"
    else:                           # RGB
        recon = recon.permute(1, 2, 0).numpy()
        cmap = None
else:
    cmap = "gray"

plt.imshow(recon, cmap=cmap)
plt.title("RVQVAE")
plt.axis("off")
plt.show()
